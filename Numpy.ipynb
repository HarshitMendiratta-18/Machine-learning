# %%
# !pip3 install numpy

# %%
import numpy as np

# %%
arr=np.array([[1,2,3],[4,5,6]])

# %%
type(arr) #type of array
# Out:
# numpy.ndarray

# %%
arr.ndim #dimensions of array
# Out:
# 2

# %%
arr.shape # shape of array
# Out:
# (2, 3)

# %%
arr.size # size of array(tells total  number of elements)
# Out:
# 6

# %%
arr.dtype # type of elements
# Out:
# dtype('int64')

# %%
a=np.array([[1,2,3],[4,5,6]],dtype='float')
print(a)
# Out:
# [[1. 2. 3.]
#  [4. 5. 6.]]

# %%
b=np.array((1,2,3))
print(b)
# Out:
# [1 2 3]

# %%
c=np.zeros((3,2))
print(c)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
d=np.ones((2,3))
print(d)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
e = np.full((3, 3), 6, dtype = 'complex')
print(e)
# Out:
# [[6.+0.j 6.+0.j 6.+0.j]
#  [6.+0.j 6.+0.j 6.+0.j]
#  [6.+0.j 6.+0.j 6.+0.j]]

# %%
f = np.random.random((2,2))
print(f)
# Out:
# [[0.80605174 0.46057194]
#  [0.40050093 0.37748265]]

# %%
g=np.arange(0,30,5)
print(g)
# Out:
# [ 0  5 10 15 20 25]

# %%
h=np.linspace(0,30,5)
print(h)
# Out:
# [ 0.   7.5 15.  22.5 30. ]

# %%
# an exemplar array
arr = np.array([[-1, 2, 0, 4],
                [4, -0.5, 6, 0],
                [2.6, 0, 7, 8],
                [3, -7, 4, 2.0]])

# slicing
temp = arr[:2, ::2]
print(temp)
# Out:
# [[-1.  0.]
#  [ 4.  6.]]

# %%
temp = arr[[0, 1, 2, 3], [3, 2, 1, 0]]
print("\nElements at indices (0, 3), (1, 2), (2, 1), (3, 0):\n", temp)
# Out:
# Elements at indices (0, 3), (1, 2), (2, 1), (3, 0):
#  [4. 6. 0. 3.]

# %%
a = np.array([1, 2, 5, 3])

# add 1 to every element
print("Adding 1 to every element:", a+1)

# subtract 3 from each element
print("Subtracting 3 from each element:", a-3)

# multiply each element by 10
print("Multiplying each element by 10:", a*10)

# square each element
print("Squaring each element:", a**2)

# modify existing array
a *= 2
print("Doubled each element of original array:", a)

# transpose of array 
a = np.array([[1, 2, 3], [3, 4, 5], [9, 6, 0]])
print("\nOriginal array:\n", a)
print("Transpose of array:\n", a.T)
# Out:
# Adding 1 to every element: [2 3 6 4]
# Subtracting 3 from each element: [-2 -1  2  0]
# Multiplying each element by 10: [10 20 50 30]
# Squaring each element: [ 1  4 25  9]
# Doubled each element of original array: [ 2  4 10  6]
#
# Original array:
#  [[1 2 3]
#  [3 4 5]
#  [9 6 0]]
# Transpose of array:
#  [[1 3 9]
#  [2 4 6]
#  [3 5 0]]
